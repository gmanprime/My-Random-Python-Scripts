# %% [markdown]
# # IMPORTS
# This is where all the script imports are handled.

# %%
import numpy as np
from pprint import pprint as pp

# import matplotlib.pyplot as plt

# %%
x = np.random.randn(3, 100)

pp(x)
# Out:
# array([[-2.81013046e-01, -6.59243884e-01, -4.60849706e-01,
#         -4.78454664e-01,  6.22924339e-01, -3.71953432e-01,
#          2.03898473e-01,  2.58681973e-01, -9.36911593e-01,
#          4.81201150e-01,  4.20914599e-01, -1.49176716e-01,
#         -1.48451840e-01,  6.61093958e-01, -1.60029809e-01,
#         -1.73141523e+00, -2.92111265e-01,  7.45474932e-01,
#         -6.48070048e-01, -5.21819527e-01,  1.00806970e+00,
#         -6.30201146e-01, -1.37043281e+00,  1.44983798e-01,
#          1.95117325e+00,  9.19058425e-03,  1.66550185e+00,
#          1.60141609e-01, -8.78641088e-01, -2.21819041e+00,
#         -9.08174116e-01, -1.01259891e+00,  5.08281237e-04,
#          7.25433472e-01,  3.79472431e-01, -3.91595366e-01,
#          3.41071529e-01,  9.33623806e-01, -1.42256899e-01,
#          7.13944533e-01,  8.11246493e-01, -3.53009181e-01,
#          8.77225547e-03, -4.49954699e-01, -1.97248370e-01,
#          7.10519970e-01,  6.78510565e-01,  5.44780370e-01,
# ...
